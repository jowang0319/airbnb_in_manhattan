# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("listings.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40227 entries, 0 to 40226
# Data columns (total 95 columns):
# id                                  40227 non-null int64
# listing_url                         40227 non-null object
# scrape_id                           40227 non-null int64
# last_scraped                        40227 non-null object
# name                                40227 non-null object
# summary                             38629 non-null object
# space                               27703 non-null object
# description                         40217 non-null object
# experiences_offered                 40227 non-null object
# neighborhood_overview               23133 non-null object
# notes                               14757 non-null object
# transit                             24982 non-null object
# access                              23421 non-null object
# interaction                         22475 non-null object
# ...

# %%
new = df[['id','name','host_id','neighbourhood_group_cleansed','zipcode','latitude','longitude','room_type','bedrooms','square_feet','price','number_of_reviews',
'review_scores_rating','accommodates','bathrooms','beds','host_total_listings_count']]

# %%
new
# Out:
#              id                                               name    host_id  \
# 0        685006                       Best Studio on Prospect Park    3493067
# 1       9461238                   1 bedrms Williamsburg 1st Stop L   49027539
# 2       4873690                Private room, 10min to Times Square    4712698
# 3      12738047                clean and tidy separated livingroom   21492250
# 4      15359479                  Awesome One Bedroom Gramercy Park    5460788
# 5      14179829    HUGE zen room, queen bed in beautiful Sunnyside   31913440
# 6        810483        Beautiful, central,sunny, quiet  shared apt    4260966
# 7       7364064                  VERY Spacious 3BR in East Village   37241813
# 8       9854420                      Beautiful one bedroom in Soho   33889947
# 9       4349358                  Spacious UWS Apt. by Central Park    4158981
# 10      9330135                Brand new 1 BR apt Steps from train   48423154
# ...

# %%
manhattan = new[new['neighbourhood_group_cleansed']=='Manhattan']

# %%
manhattan
# Out:
#              id                                               name   host_id  \
# 3      12738047                clean and tidy separated livingroom  21492250
# 4      15359479                  Awesome One Bedroom Gramercy Park   5460788
# 6        810483        Beautiful, central,sunny, quiet  shared apt   4260966
# 7       7364064                  VERY Spacious 3BR in East Village  37241813
# 8       9854420                      Beautiful one bedroom in Soho  33889947
# 9       4349358                  Spacious UWS Apt. by Central Park   4158981
# 12      1465807                    Park Views! Upper Manhattan 1BR   7812791
# 13     11165126                 The Best Of UNION SQUARE & CHELSEA   1997269
# 14     16014791   Nice clean style apt. Central midtwn near Javits    801883
# 16      7344066                    Gorgeous West Village 1-bdm apt   6573741
# 20     11296173                   Lovely NYC Apartment  July 16-30  21722916
# ...

# %%
manhattan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19248 entries, 3 to 40220
# Data columns (total 17 columns):
# id                              19248 non-null int64
# name                            19248 non-null object
# host_id                         19248 non-null int64
# neighbourhood_group_cleansed    19248 non-null object
# zipcode                         18996 non-null object
# latitude                        19248 non-null float64
# longitude                       19248 non-null float64
# room_type                       19248 non-null object
# bedrooms                        19226 non-null float64
# square_feet                     269 non-null float64
# price                           19248 non-null object
# number_of_reviews               19248 non-null int64
# review_scores_rating            14564 non-null float64
# accommodates                    19248 non-null int64
# bathrooms                       19166 non-null float64
# ...

# %%
def money_to_float(money_str):
    return float(money_str.replace("$","").replace(",",""))

# %%
manhattan['price'].apply(money_to_float)
# Out:
# 3          80.0
# 4         200.0
# 6         119.0
# 7        2000.0
# 8         200.0
# 9         125.0
# 12         79.0
# 13        245.0
# 14        110.0
# 16        250.0
# 20        400.0
# 22        190.0
# 23        100.0
# 24         60.0
# 25         80.0
# 28        149.0
# 33        110.0
# 34        375.0
# 35         75.0
# 36        200.0
# 38         85.0
# 40        206.0
# 41        250.0
# 43        125.0
# 44         60.0
# 48         99.0
# 49        140.0
# 50        575.0
# 53         99.0
# 54        300.0
#           ...
# 40135     320.0
# 40139      80.0
# 40140      95.0
# 40141     180.0
# 40142     225.0
# 40144      85.0
# 40145      55.0
# 40146     100.0
# 40149     150.0
# 40156      45.0
# 40163     100.0
# 40165      94.0
# 40176     195.0
# 40179     325.0
# 40182     185.0
# 40183     165.0
# 40185     130.0
# 40186      55.0
# 40187     199.0
# 40193     299.0
# 40203      85.0
# 40204     475.0
# 40213     125.0
# 40214      86.0
# ...

# %%
manhattan['price']=manhattan['price'].apply(money_to_float)
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
new['price'] = new['price'].apply(money_to_float)
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
new['price'].hist(bins=30)

# %%
new['price'].describe()
# Out:
# count    40227.000000
# mean       147.475899
# std        210.224914
# min         10.000000
# 25%         70.000000
# 50%        109.000000
# 75%        175.000000
# max       9999.000000
# Name: price, dtype: float64

# %%
new[new['price']==9999]
# Out:
#             id                                 name  host_id  \
# 9419   9528920  Quiet, Clean, Lit @ LES & Chinatown  3906464
# 32120  4737930                   Spanish Harlem Apt  1235070
#
#       neighbourhood_group_cleansed zipcode   latitude  longitude  \
# 9419                     Manhattan   10002  40.713554 -73.985069
# 32120                    Manhattan   10029  40.792645 -73.938976
#
#              room_type  bedrooms  square_feet   price  number_of_reviews  \
# 9419      Private room       1.0          NaN  9999.0                  6
# 32120  Entire home/apt       2.0          NaN  9999.0                  1
#
#        review_scores_rating  accommodates  bathrooms  beds  \
# 9419                   87.0             2        1.0   1.0
# 32120                 100.0             4        1.0   2.0
#
#        host_total_listings_count
# 9419                         2.0
# 32120                        1.0

# %%
clean = new[new['price']<=1000]

# %%
clean['price'].hist()

# %%
manhattan[manhattan['price']<=1000]['price'].hist()

# %%
new.groupby(by='room_type').count().plot(kind='barh',y='id')

# %%
manhattan.groupby(by='room_type').count().plot(kind='barh',y='id')

# %%
new['accommodates'].hist()

# %%
manhattan['accommodates'].hist()

# %%
new['beds'].hist()

# %%
manhattan['beds'].hist()

# %%
new['review_scores_rating'].hist()

# %%
manhattan['review_scores_rating'].hist()

# %%
manhattan['host_total_listings_count'].describe()
# Out:
# /usr/local/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    19230.000000
# mean         2.503068
# std         21.503594
# min          0.000000
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max        777.000000
# Name: host_total_listings_count, dtype: float64

# %%
manhattan[manhattan['host_total_listings_count']==1].count()
# Out:
# id                              14188
# name                            14188
# host_id                         14188
# neighbourhood_group_cleansed    14188
# zipcode                         13973
# latitude                        14188
# longitude                       14188
# room_type                       14188
# bedrooms                        14168
# square_feet                       193
# price                           14188
# number_of_reviews               14188
# review_scores_rating            10423
# accommodates                    14188
# bathrooms                       14140
# beds                            14162
# host_total_listings_count       14188
# dtype: int64

# %%
manhattan[manhattan['host_total_listings_count']==2].count()
# Out:
# id                              2836
# name                            2836
# host_id                         2836
# neighbourhood_group_cleansed    2836
# zipcode                         2814
# latitude                        2836
# longitude                       2836
# room_type                       2836
# bedrooms                        2835
# square_feet                       39
# price                           2836
# number_of_reviews               2836
# review_scores_rating            2335
# accommodates                    2836
# bathrooms                       2826
# beds                            2832
# host_total_listings_count       2836
# dtype: int64

# %%
manhattan[manhattan['host_total_listings_count']<=10].count()
# Out:
# id                              18894
# name                            18894
# host_id                         18894
# neighbourhood_group_cleansed    18894
# zipcode                         18642
# latitude                        18894
# longitude                       18894
# room_type                       18894
# bedrooms                        18872
# square_feet                       265
# price                           18894
# number_of_reviews               18894
# review_scores_rating            14298
# accommodates                    18894
# bathrooms                       18813
# beds                            18862
# host_total_listings_count       18894
# dtype: int64

# %%
manhattan.count()
# Out:
# id                              19248
# name                            19248
# host_id                         19248
# neighbourhood_group_cleansed    19248
# zipcode                         18996
# latitude                        19248
# longitude                       19248
# room_type                       19248
# bedrooms                        19226
# square_feet                       269
# price                           19248
# number_of_reviews               19248
# review_scores_rating            14564
# accommodates                    19248
# bathrooms                       19166
# beds                            19215
# host_total_listings_count       19230
# dtype: int64

# %%
manhattan.to_csv('data.csv')
